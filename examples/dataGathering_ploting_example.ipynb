# %% [markdown]
# ## Downloading Historical OHLCV Data

# %%
from pycoin.data_gathering import KlineData_Fetcher
import datetime as dt

df = KlineData_Fetcher(symbol="BTC/USDT", 
                       timeframe="4h",
                       data_exchange="binance",
                       since = dt.datetime(2020, 1, 1)
                       )

df
# Out:
# binance|4h|BTC/USDT
#                   untill 2020-06-15 20:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2020-11-29 07:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2021-05-14 20:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2021-10-28 07:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2022-04-12 20:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2022-09-26 07:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2023-03-11 19:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2023-08-25 07:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2024-02-07 19:30:00 fetched
#
#
# binance|4h|BTC/USDT
#                   untill 2024-02-27 11:30:00 fetched
#                                Open      High       Low     Close  \
# Datetime
# 2020-01-01 00:00:00+00:00   7195.24   7245.00   7175.46   7225.01
# 2020-01-01 04:00:00+00:00   7225.00   7236.27   7199.11   7209.83
# 2020-01-01 08:00:00+00:00   7209.83   7237.73   7180.00   7197.20
# 2020-01-01 12:00:00+00:00   7197.20   7255.00   7196.15   7234.19
# 2020-01-01 16:00:00+00:00   7234.20   7249.99   7214.00   7229.48
# ...                             ...       ...       ...       ...
# 2024-02-26 12:00:00+00:00  51090.01  52847.84  50957.00  52842.32
# 2024-02-26 16:00:00+00:00  52842.33  54512.02  52753.28  54487.11
# 2024-02-26 20:00:00+00:00  54487.10  54910.00  54258.20  54476.47
# 2024-02-27 00:00:00+00:00  54476.48  57073.84  54450.13  55667.60
# 2024-02-27 04:00:00+00:00  55667.60  56448.00  55576.12  56059.08
#
#                                  Volume
# Datetime
# 2020-01-01 00:00:00+00:00   2833.749180
# 2020-01-01 04:00:00+00:00   2061.295051
# 2020-01-01 08:00:00+00:00   3166.654361
# 2020-01-01 12:00:00+00:00   3492.537459
# 2020-01-01 16:00:00+00:00   2980.583291
# ...                                 ...
# 2024-02-26 12:00:00+00:00  11761.169400
# 2024-02-26 16:00:00+00:00  19931.382790
# 2024-02-26 20:00:00+00:00   8320.092070
# 2024-02-27 00:00:00+00:00  17222.694300
# 2024-02-27 04:00:00+00:00   8813.406040
#
# [9110 rows x 5 columns]

# %% [markdown]
# ## Plotting Market

# %%
from pycoin.plotting import Market_Plotter

plots = Market_Plotter(OHLCV_df=df)

# %%
plots.plot_market()

# %% [markdown]
# ##

# %% [markdown]
# ## trend analysis

# %%
from pycoin.data_gathering import get_market_High_Lows, Trend_Evaluator

highs_ind, lows_ind = get_market_High_Lows(df, candle_range = 100)
highs_ind
# Out:
# [261,
#  767,
#  917,
#  1378,
#  2241,
#  2506,
#  2627,
#  2815,
#  2963,
#  3190,
#  3274,
#  3690,
#  3951,
#  4077,
#  4360,
#  4630,
#  4749,
#  4906,
#  5290,
#  5742,
#  5919,
#  6047,
#  6234,
#  6472,
#  6768,
#  6856,
#  7195,
#  7464,
#  7738,
#  8020,
#  8627,
#  8829,
#  9108]

# %%
# Out:
# 2
